# %%
print('hola')
# Out:
# hola

# %%
print('Hola amigos)
# Out:
#   Cell In[3], line 1
#     print('Hola amigos)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hola buenos'+ '\n' + ' amigos')
# Out:
# Hola buenos
#  amigos

# %%
print('Hola buenos','amigos')
# Out:
# Hola buenos amigos

# %%
w = 100

i = 2 + w

i = i - 3

print(i)
# Out:
# 99

# %%
w = 10

i = w - 4 * 2

print('el resultado es:', i)
print('el resultado es:'+ str(i))
# Out:
# el resultado es: 2
# el resultado es:2

# %%
w = 100 # w es un número entero (int:integer )

i = w//2 # i: es un número flotante (float: decimal)

print(i)
# Out:
# 50

# %%
# Modulo
# a%b = m

m = 7%3

print(m)
# Out:
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
i = 2 * 3 + 4 - 12 ** 5

print('El resultado de 2 * 3 + 4 - 12 ** 5 es',i)
# Out:
# El resultado de 2 * 3 + 4 - 12 ** 5 es -248822

# %%
w = 2
x = 3
y = 4
z = 12
a = 5

resultado = w * x + y - z**a

print(f'El resultado de {w} * {x} + {y} - {z}**{a} es {resultado:,}')
# Out:
# El resultado de 2 * 3 + 4 - 12**5 es -248,822

# %%
edad = int(input())

print('Mi edad en 5 años más será',edad+5)
# Out:
# 3
# Mi edad en 5 años más será 8

# %%
numero_pi = float(input())

print(f'el numero pi es: {numero_pi}')
# Out:
# 56
# el numero pi es: 56.0

# %%
largo = float(input('Ingrese el largo: '))
ancho = float(input('Ingrese el ancho: '))

area = largo * ancho

print(f'El área de un rectangulo de largo {largo} y ancho {ancho} es', area)
# Out:
# Ingrese el largo: 5
# Ingrese el ancho: 2.5
# El área de un rectangulo de largo 5.0 y ancho 2.5 es 12.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
resultado = 23 == 12

print(resultado)
# Out:
# False

# %%
resultado = (25>1) and (10>2)

print(f'El resultado de la Expresión {resultado} es:', resultado)
# Out:
# El resultado de la Expresión True es: True

# %%
print('estoy antes del if')

if True:
  print('entoy en el bloque')

print('estoy fuera del if')
# Out:
# estoy antes del if
# entoy en el bloque
# estoy fuera del if

# %%
respuesta = input('Te gustan los dulces? ') # Lee respuesta

if respuesta.lower() == 'si':
  print('Respuesta =', respuesta)
  print('A mi tambien')
else:
  print('Respuesta =', respuesta)
  print('Que bueno los dulces hacen mal :P')
# Out:
# Te gustan los dulces? no
# Respuesta = no
# Que bueno los dulces hacen mal :P
